# %%
import mediapipe as mp
print(mp.__version__)
print(mp.solutions.face_mesh)
# Out:
# WARNING:tensorflow:From c:\Users\User\Desktop\OpenCV\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 0.10.14
# <module 'mediapipe.python.solutions.face_mesh' from 'c:\\Users\\User\\Desktop\\OpenCV\\venv\\lib\\site-packages\\mediapipe\\python\\solutions\\face_mesh.py'>
